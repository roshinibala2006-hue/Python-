# %%
import numpy as np
d ={ 'A':[1,2, np.nan],'B':[5, np.nan, np.nan],'c':[1,2,3]}

# %%
import pandas as pd
df = pd.DataFrame(d)

# %%
df
# Out:
#      A    B  c
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  c
# 0  1.0  5.0  1

# %%
df.dropna(axis = 0)
# Out:
#      A    B  c
# 0  1.0  5.0  1

# %%
df.dropna(axis = 1)
# Out:
#    c
# 0  1
# 1  2
# 2  3

# %%
df
# Out:
#      A    B  c
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value = 'Filling Value')
# Out:
#                A              B  c
# 0            1.0            5.0  1
# 1            2.0  Filling Value  2
# 2  Filling Value  Filling Value  3

# %%
df = pd.DataFrame(d)

# %%
a = df['A'].fillna(value = df['A'].mean())

# %%
a
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B  c
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df['A'].fillna(value = df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B  c
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna??

# %%
df['A'].fillna(value = df['A'].mean(), inplace = True)
# Out:
# /tmp/ipython-input-2171742998.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['A'].fillna(value = df['A'].mean(), inplace = True)

# %%
df
# Out:
#      A    B  c
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  1.5  NaN  3

# %%
data = {'company':['Google','Google','MSFT','FB','FB','IBM'],
        'person': ['Sam','Nihad','Any','Van','Rakib','Ovi'],
        'Sales': [200, 120, 340, 124, 243, 350]

}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   company person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
byComp = df.groupby('Company')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2756638908.py in <cell line: 0>()
# ----> 1 byComp = df.groupby('Company')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'Company'

# %%
byComp.mean(numeric_only=True)
# Out:
#          Sales
# company
# FB       183.5
# Google   160.0
# IBM      350.0
# MSFT     340.0

# %%
byComp.sum()
# Out:
#            person  Sales
# company
# FB       VanRakib    367
# Google   SamNihad    320
# IBM           Ovi    350
# MSFT          Any    340

# %%
df
# Out:
#   company person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df.groupby('company').count()
# Out:
#          person  Sales
# company
# FB            2      2
# Google        2      2
# IBM           1      1
# MSFT          1      1

# %%
df
# Out:
#   company person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df.groupby('company').describe()
# Out:
#         Sales
#         count   mean        std    min     25%    50%     75%    max
# company
# FB        2.0  183.5  84.145707  124.0  153.75  183.5  213.25  243.0
# Google    2.0  160.0  56.568542  120.0  140.00  160.0  180.00  200.0
# IBM       1.0  350.0        NaN  350.0  350.00  350.0  350.00  350.0
# MSFT      1.0  340.0        NaN  340.0  340.00  340.0  340.00  340.0

# %%
df1 = pd.DataFrame(np.random.randint(1, 20, size = (4, 3)), [1,2,3,4], ['W', 'X', 'Y'])

# %%
df2 = pd.DataFrame(np.random.randint(20,40, size = (4, 3)), [5,6,7,8], ['W', 'X', 'Y'])

# %%
df3 = pd.DataFrame(np.random.randint(40,60, size = (4, 3)), [9,10,11,12], ['W', 'X', 'Y'])

# %%
df1
# Out:
#     W   X   Y
# 1   6  11   8
# 2  10  19   4
# 3   6  15   2
# 4   4   1  16

# %%
df2
# Out:
#     W   X   Y
# 5  37  39  33
# 6  34  36  32
# 7  29  32  39
# 8  35  27  35

# %%
df3
# Out:
#      W   X   Y
# 9   44  56  44
# 10  41  41  51
# 11  53  41  46
# 12  51  44  53

# %%
farme = [df1, df2, df3]

# %%
pd.concat(farme)
# Out:
#      W   X   Y
# 1    6  11   8
# 2   10  19   4
# 3    6  15   2
# 4    4   1  16
# 5   37  39  33
# 6   34  36  32
# 7   29  32  39
# 8   35  27  35
# 9   44  56  44
# 10  41  41  51
# 11  53  41  46
# 12  51  44  53

# %%
pd.concat(farme,axis = 1)
# Out:
#        W     X     Y     W     X     Y     W     X     Y
# 1    6.0  11.0   8.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2   10.0  19.0   4.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3    6.0  15.0   2.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4    4.0   1.0  16.0   NaN   NaN   NaN   NaN   NaN   NaN
# 5    NaN   NaN   NaN  37.0  39.0  33.0   NaN   NaN   NaN
# 6    NaN   NaN   NaN  34.0  36.0  32.0   NaN   NaN   NaN
# 7    NaN   NaN   NaN  29.0  32.0  39.0   NaN   NaN   NaN
# 8    NaN   NaN   NaN  35.0  27.0  35.0   NaN   NaN   NaN
# 9    NaN   NaN   NaN   NaN   NaN   NaN  44.0  56.0  44.0
# 10   NaN   NaN   NaN   NaN   NaN   NaN  41.0  41.0  51.0
# 11   NaN   NaN   NaN   NaN   NaN   NaN  53.0  41.0  46.0
# 12   NaN   NaN   NaN   NaN   NaN   NaN  51.0  44.0  53.0

# %%
left = {
    'key': ['K0', 'K1', 'K2', 'K3'],
    'A': ['A0', 'A1', 'A2', 'A3'],
    'B': ['B0', 'B1', 'B2', 'B3']
}

# %%
right = {
    'key': ['K0', 'K1', 'K2', 'K3'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    'D': ['D0', 'D1', 'D2', 'D3']
}

# %%
left = pd.DataFrame(left)

# %%
right = pd.DataFrame(right)

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(left, right, on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
pd.merge??

# %%
left = {
    'A': ['A0', 'A1', 'A2'],
    'B': ['B0', 'B1', 'B2']
}

# %%
right = {
    'C': ['C0', 'C1', 'C2'],
    'D': ['D0', 'D1', 'D2']
}

# %%
left = pd.DataFrame(left, index = ['K0', 'K1', 'K2'])

# %%
left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right
# Out:
# {'C': ['C0', 'C1', 'C2'], 'D': ['D0', 'D1', 'D2']}

# %%
right = pd.DataFrame(right, index = ['K0', 'K1', 'K2'])
left.join(right, how = 'inner')
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K1  A1  B1  C1  D1
# K2  A2  B2  C2  D2
