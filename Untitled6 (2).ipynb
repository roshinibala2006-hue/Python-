# %%
import numpy as np

d={
    'A':[1,2,np.nan],
    'B':[5,np.nan,np.nan],
    'C':[1,2,3]
}

# %%
import pandas as pd
df=pd.DataFrame(d)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=0)
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value='Filling Value')
# Out:
#                A              B  C
# 0            1.0            5.0  1
# 1            2.0  Filling Value  2
# 2  Filling Value  Filling Value  3

# %%
df=pd.DataFrame(d)

# %%
a=df['A'].fillna(value=df['A'].mean())

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
a
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna??

# %%
df['A'].fillna(value=df['A'].mean(), inplace=True)
# Out:
# /tmp/ipython-input-1576873578.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['A'].fillna(value=df['A'].mean(),inplace=True)

# %%
data={
    'Company':['Google','Goodle','MSFT','FB','FB','IBM'],
    'Person':['Sam','Nihad','Any','Van','Rakib','Ovi'],
    'Sales':[200,120,340,124,243,350]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Goodle  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
byComp=df.groupby('Company')

# %%
byComp.mean(numeric_only=True)
# Out:
#          Sales
# Company
# FB       183.5
# Goodle   120.0
# Google   200.0
# IBM      350.0
# MSFT     340.0

# %%
byComp.sum()
# Out:
#            Person  Sales
# Company
# FB       VanRakib    367
# Goodle      Nihad    120
# Google        Sam    200
# IBM           Ovi    350
# MSFT          Any    340

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Goodle  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
byComp.std(numeric_only=True)
# Out:
#              Sales
# Company
# FB       84.145707
# Goodle         NaN
# Google         NaN
# IBM            NaN
# MSFT           NaN

# %%
df.groupby('Company').count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# Goodle        1      1
# Google        1      1
# IBM           1      1
# MSFT          1      1

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Goodle  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean        std    min     25%    50%     75%    max
# Company
# FB        2.0  183.5  84.145707  124.0  153.75  183.5  213.25  243.0
# Goodle    1.0  120.0        NaN  120.0  120.00  120.0  120.00  120.0
# Google    1.0  200.0        NaN  200.0  200.00  200.0  200.00  200.0
# IBM       1.0  350.0        NaN  350.0  350.00  350.0  350.00  350.0
# MSFT      1.0  340.0        NaN  340.0  340.00  340.0  340.00  340.0

# %%
df1=pd.DataFrame(np.random.randint(1,20,size=(4,3)),[1,2,3,4], ['W','X','Y'])

# %%
df2=pd.DataFrame(np.random.randint(20,40,size=(4,3)),[5,6,7,8], ['W','X','Y'])

# %%
df3=pd.DataFrame(np.random.randint(40,60,size=(4,3)),[9,10,11,12],['W','X','Y'])

# %%
df1
# Out:
#     W   X   Y
# 1  16   4  18
# 2  16   2   8
# 3   7   3   7
# 4  14  16  12

# %%
df2
# Out:
#     W   X   Y
# 5  33  22  36
# 6  29  38  39
# 7  23  27  35
# 8  20  30  36

# %%
df3
# Out:
#      W   X   Y
# 9   58  50  56
# 10  55  41  57
# 11  53  51  58
# 12  55  53  58

# %%
farme=[df1,df2,df3]

# %%
pd.concat(farme)
# Out:
#      W   X   Y
# 1   16   4  18
# 2   16   2   8
# 3    7   3   7
# 4   14  16  12
# 5   33  22  36
# 6   29  38  39
# 7   23  27  35
# 8   20  30  36
# 9   58  50  56
# 10  55  41  57
# 11  53  51  58
# 12  55  53  58

# %%
pd.concat(farme,axis=1)
# Out:
#        W     X     Y     W     X     Y     W     X     Y
# 1   16.0   4.0  18.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2   16.0   2.0   8.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3    7.0   3.0   7.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4   14.0  16.0  12.0   NaN   NaN   NaN   NaN   NaN   NaN
# 5    NaN   NaN   NaN  33.0  22.0  36.0   NaN   NaN   NaN
# 6    NaN   NaN   NaN  29.0  38.0  39.0   NaN   NaN   NaN
# 7    NaN   NaN   NaN  23.0  27.0  35.0   NaN   NaN   NaN
# 8    NaN   NaN   NaN  20.0  30.0  36.0   NaN   NaN   NaN
# 9    NaN   NaN   NaN   NaN   NaN   NaN  58.0  50.0  56.0
# 10   NaN   NaN   NaN   NaN   NaN   NaN  55.0  41.0  57.0
# 11   NaN   NaN   NaN   NaN   NaN   NaN  53.0  51.0  58.0
# 12   NaN   NaN   NaN   NaN   NaN   NaN  55.0  53.0  58.0

# %%
left={
    'key':['k0','k1','k2','k3'],
    'A':[10,20,30,40],
    'B':[1,2,3,4]
}

# %%
right={
    'key':['ko','k1','k2','k3'],
    'C':[100,200,300,400],
  'D':[11,12,13,14]
}

# %%
left=pd.DataFrame(left)

# %%
right=pd.DataFrame(right)

# %%
left
# Out:
#   key   A  B
# 0  k0  10  1
# 1  k1  20  2
# 2  k2  30  3
# 3  k3  40  4

# %%
right
# Out:
#   key    C   D
# 0  ko  100  11
# 1  k1  200  12
# 2  k2  300  13
# 3  k3  400  14

# %%
pd.merge(left,right,on='key')
# Out:
#   key   A  B    C   D
# 0  k1  20  2  200  12
# 1  k2  30  3  300  13
# 2  k3  40  4  400  14

# %%
df['col2'].apply(times2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3713377580.py in <cell line: 0>()
# ----> 1 df['col2'].apply(times2)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
# ...

# %%
left={
    'A':['A0','A1','A2'],
    'B':['B0','B1','B2']
}

# %%
right={
    'C':['C0','C1','C2'],
    'D':['D0','D1','D2']
}

# %%
left=pd.DataFrame(left,index=['k0','k1','k2'])

# %%
right=pd.DataFrame(right,index=['k0','k1','k2'])

# %%
left
# Out:
#      A   B
# k0  A0  B0
# k1  A1  B1
# k2  A2  B2

# %%
right
# Out:
#      C   D
# k0  C0  D0
# k1  C1  D1
# k2  C2  D2

# %%
left.join(right,how='inner')
# Out:
#      A   B   C   D
# k0  A0  B0  C0  D0
# k1  A1  B1  C1  D1
# k2  A2  B2  C2  D2

# %%
left.join??

# %%
df=pd.DataFrame({
    'col1':[444,555,666,444],
    'col2':[1,2,3,4],
    'col3':['abc','def','ghi','xyz']
})

# %%
df
# Out:
#    col1  col2 col3
# 0   444     1  abc
# 1   555     2  def
# 2   666     3  ghi
# 3   444     4  xyz

# %%
df['col1'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col1'].nunique()
# Out:
# 3

# %%
df['col1'].value_counts()
# Out:
# col1
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %%
def times2(x):
    return 2*x

# %%
df['col2'].apply(times2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3713377580.py in <cell line: 0>()
# ----> 1 df['col2'].apply(times2)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
# ...

# %%
df['col2'].apply(lambda x:x**2)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col2, dtype: int64

# %%
df = pd.read_csv(r"/content/Hospital General Information.csv", encoding='latin1')

# %%
df
# Out:
#       Provider ID                     Hospital Name  \
# 0           10001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1           10005     MARSHALL MEDICAL CENTER SOUTH
# 2           10006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3           10007          MIZELL MEMORIAL HOSPITAL
# 4           10008       CRENSHAW COMMUNITY HOSPITAL
# ...           ...                               ...
# 4807       670118              FIRST TEXAS HOSPITAL
# 4808       640001       LBJ TROPICAL MEDICAL CENTER
# 4809       650001  GUAM MEMORIAL HOSPITAL AUTHORITY
# 4810       650003        GUAM REGIONAL MEDICAL CITY
# 4811       660001        COMMONWEALTH HEALTH CENTER
#
#                             Address       City State  ZIP Code County Name  \
# 0            1108 ROSS CLARK CIRCLE     DOTHAN    AL     36301     HOUSTON
# 1        2505 U S HIGHWAY 431 NORTH       BOAZ    AL     35957    MARSHALL
# 2                205 MARENGO STREET   FLORENCE    AL     35631  LAUDERDALE
# ...

# %%
df.head(10)
# Out:
#    Provider ID                     Hospital Name  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1        10005     MARSHALL MEDICAL CENTER SOUTH
# 2        10006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3        10007          MIZELL MEMORIAL HOSPITAL
# 4        10008       CRENSHAW COMMUNITY HOSPITAL
# 5        10011                 ST VINCENT'S EAST
# 6        10012    DEKALB REGIONAL MEDICAL CENTER
# 7        10016     SHELBY BAPTIST MEDICAL CENTER
# 8        10018             CALLAHAN EYE HOSPITAL
# 9        10019    HELEN KELLER MEMORIAL HOSPITAL
#
#                         Address        City State  ZIP Code County Name  \
# 0        1108 ROSS CLARK CIRCLE      DOTHAN    AL     36301     HOUSTON
# 1    2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957    MARSHALL
# 2            205 MARENGO STREET    FLORENCE    AL     35631  LAUDERDALE
# 3                 702 N MAIN ST         OPP    AL     36467   COVINGTON
# ...

# %%
df.tail()
# Out:
#       Provider ID                     Hospital Name  \
# 4807       670118              FIRST TEXAS HOSPITAL
# 4808       640001       LBJ TROPICAL MEDICAL CENTER
# 4809       650001  GUAM MEMORIAL HOSPITAL AUTHORITY
# 4810       650003        GUAM REGIONAL MEDICAL CITY
# 4811       660001        COMMONWEALTH HEALTH CENTER
#
#                             Address       City State  ZIP Code County Name  \
# 4807                9922 LOUETTA RD    HOUSTON    TX     77070      HARRIS
# 4808                FAGAALU VILLAGE  PAGO PAGO    AS     96799         NaN
# 4809  85O GOV CARLOS G CAMACHO ROAD   TAMUNING    GU     96913         NaN
# 4810                    133 ROUTE 3     DEDEDO    GU     96929         NaN
# 4811   PO BOX 409CK, NAVY HILL ROAD    GARAPAN    MP     96950         NaN
#
#       Phone Number         Hospital Type  \
# 4807    8442641435  Acute Care Hospitals
# 4808    6846334590  Acute Care Hospitals
# 4809    6716472552  Acute Care Hospitals
# ...

# %%
df.columns
# Out:
# Index(['Provider ID', 'Hospital Name', 'Address', 'City', 'State', 'ZIP Code',
#        'County Name', 'Phone Number', 'Hospital Type', 'Hospital Ownership',
#        'Emergency Services', 'Meets criteria for meaningful use of EHRs',
#        'Hospital overall rating', 'Hospital overall rating footnote',
#        'Mortality national comparison',
#        'Mortality national comparison footnote',
#        'Safety of care national comparison',
#        'Safety of care national comparison footnote',
#        'Readmission national comparison',
#        'Readmission national comparison footnote',
#        'Patient experience national comparison',
#        'Patient experience national comparison footnote',
#        'Effectiveness of care national comparison',
#        'Effectiveness of care national comparison footnote',
#        'Timeliness of care national comparison',
#        'Timeliness of care national comparison footnote',
# ...

# %%
df.columns.to_list()
# Out:
# ['Provider ID',
#  'Hospital Name',
#  'Address',
#  'City',
#  'State',
#  'ZIP Code',
#  'County Name',
#  'Phone Number',
#  'Hospital Type',
#  'Hospital Ownership',
#  'Emergency Services',
#  'Meets criteria for meaningful use of EHRs',
#  'Hospital overall rating',
#  'Hospital overall rating footnote',
#  'Mortality national comparison',
#  'Mortality national comparison footnote',
#  'Safety of care national comparison',
#  'Safety of care national comparison footnote',
#  'Readmission national comparison',
#  'Readmission national comparison footnote',
#  'Patient experience national comparison',
#  'Patient experience national comparison footnote',
#  'Effectiveness of care national comparison',
#  'Effectiveness of care national comparison footnote',
#  'Timeliness of care national comparison',
#  'Timeliness of care national comparison footnote',
#  'Efficient use of medical imaging national comparison',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4812 entries, 0 to 4811
# Data columns (total 28 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Provider ID                                                    4812 non-null   int64
#  1   Hospital Name                                                  4812 non-null   object
#  2   Address                                                        4812 non-null   object
#  3   City                                                           4812 non-null   object
#  4   State                                                          4812 non-null   object
#  5   ZIP Code                                                       4812 non-null   int64
#  6   County Name                                                    4797 non-null   object
# ...

# %%
df.nunique()
# Out:
# Provider ID                                                      4812
# Hospital Name                                                    4623
# Address                                                          4784
# City                                                             2947
# State                                                              56
# ZIP Code                                                         4416
# County Name                                                      1563
# Phone Number                                                     4794
# Hospital Type                                                       3
# Hospital Ownership                                                 10
# Emergency Services                                                  2
# Meets criteria for meaningful use of EHRs                           2
# Hospital overall rating                                             6
# ...

# %%
df.head()
# Out:
#    Provider ID                     Hospital Name                     Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1        10005     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 2        10006    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET
# 3        10007          MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 4        10008       CRENSHAW COMMUNITY HOSPITAL         101 HOSPITAL CIRCLE
#
#        City State  ZIP Code County Name  Phone Number         Hospital Type  \
# 0    DOTHAN    AL     36301     HOUSTON    3347938701  Acute Care Hospitals
# 1      BOAZ    AL     35957    MARSHALL    2565938310  Acute Care Hospitals
# 2  FLORENCE    AL     35631  LAUDERDALE    2567688400  Acute Care Hospitals
# 3       OPP    AL     36467   COVINGTON    3344933541  Acute Care Hospitals
# 4   LUVERNE    AL     36049    CRENSHAW    3343353374  Acute Care Hospitals
#
# ...

# %%
df.head()
# Out:
#    Provider ID                     Hospital Name                     Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1        10005     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 2        10006    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET
# 3        10007          MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 4        10008       CRENSHAW COMMUNITY HOSPITAL         101 HOSPITAL CIRCLE
#
#        City State  ZIP Code County Name  Phone Number         Hospital Type  \
# 0    DOTHAN    AL     36301     HOUSTON    3347938701  Acute Care Hospitals
# 1      BOAZ    AL     35957    MARSHALL    2565938310  Acute Care Hospitals
# 2  FLORENCE    AL     35631  LAUDERDALE    2567688400  Acute Care Hospitals
# 3       OPP    AL     36467   COVINGTON    3344933541  Acute Care Hospitals
# 4   LUVERNE    AL     36049    CRENSHAW    3343353374  Acute Care Hospitals
#
# ...

# %%
df.describe()
# Out:
#          Provider ID      ZIP Code  Phone Number
# count    4812.000000   4812.000000  4.812000e+03
# mean   268294.422901  53990.132377  5.849100e+09
# std    157109.340215  26915.916870  2.331563e+09
# min     10001.000000    603.000000  9.369338e+08
# 25%    140185.750000  33015.250000  4.015615e+09
# 50%    260043.500000  55410.500000  6.053413e+09
# 75%    390222.250000  76035.500000  7.877574e+09
# max    670118.000000  99929.000000  9.898943e+09

# %%
df.mean(numeric_only=True)
# Out:
# Provider ID     2.682944e+05
# ZIP Code        5.399013e+04
# Phone Number    5.849100e+09
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Provider ID     2.600435e+05
# ZIP Code        5.541050e+04
# Phone Number    6.053413e+09
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# Provider ID     1.571093e+05
# ZIP Code        2.691592e+04
# Phone Number    2.331563e+09
# dtype: float64

# %%
a = 6
b = 5
a = a - 1
b = b + 1
b = b - 2
a = a -2
print("a =", a)
print("b =", b)
# Out:
# a = 3
# b = 4

# %%
a = 8
b = 16
rate_a = 1 / a
rate_b = 1 / b
combined_rate = rate_a + rate_b
total_time = 1 / combined_rate
print("Time to complete the task together:", round(total_time, 2), "hours")
# Out:
# Time to complete the task together: 5.33 hours
